# %%
from numpy import zeros, ones
from numpy.random import randn, randint

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import random
import shutil

# %%
# STORING ALL FILES IN LIST
import shutil
path=r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/NF"
i=0
arr=[]
for files in os.listdir(path):
    arr.append(files)
    #source=path+"/"+files
  #shutil.copy(source, "/content/drive/MyDrive/Colab Notebooks/data/test/Pneumonia")
print(len(arr))
# Out:
# 48290

# %%
#RNADOMLY SELECTING FEW FILES FROM THE ABOVE LIST TO PUT IN TEST FOLDER
import random

# initializing the value of n
n = 24290
  
# printing n elements from list
rand_arr=random.sample(arr, n)
print(rand_arr)
print(len(rand_arr))
# Out:
# ['00012087_059.png', '00002480_003.png', '00026148_009.png', '00011945_008.png', '00007709_000.png', '00018237_016.png', '00028808_005.png', '00027700_001.png', '00014762_000.png', '00002256_005.png', '00003945_000.png', '00000808_008.png', '00028549_010.png', '00001780_000.png', '00000211_020.png', '00001573_000.png', '00011770_002.png', '00019196_001.png', '00005847_001.png', '00023093_000.png', '00001836_107.png', '00023109_004.png', '00016063_000.png', '00018569_000.png', '00029863_007.png', '00007477_003.png', '00017187_000.png', '00022416_077.png', '00026570_001.png', '00005261_003.png', '00002351_003.png', '00027357_007.png', '00014449_002.png', '00001255_032.png', '00027879_002.png', '00020149_000.png', '00022837_041.png', '00021972_011.png', '00009349_005.png', '00021034_000.png', '00010557_001.png', '00008019_000.png', '00010555_003.png', '00012958_000.png', '00023213_000.png', '00022869_006.png', '00017369_000.png', '00022230_000.png', '00009403_000.png', '00014192_000.png
# ...

# %%
# moving RANDOMLY SELECTED FILES 
path=r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/NF"
for files in rand_arr:
      if os.path.exists(path+"/"+files):
        source=path+"/"+files
        shutil.move(source, r"/content/drive/MyDrive/NF RUS")

# %%
cou=0
for files in os.listdir("/content/drive/MyDrive/NF RUS"):
  cou=cou+1
print(cou)
# Out:
# 30362

# %%
# STORING ALL P FILES IN LIST
import shutil
path=r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/test/P"
i=0
arr=[]
for files in os.listdir(path):
    arr.append(files)
    #source=path+"/"+files
  #shutil.copy(source, "/content/drive/MyDrive/Colab Notebooks/data/test/Pneumonia")
print(len(arr))


# COPYING P FILES TO ANOTHER DIRECTORY FOR BACK UP 
#path=r"/content/drive/MyDrive/P train"
for files in arr:
      if os.path.exists(path+"/"+files):
        source=path+"/"+files
        shutil.copy(source, r"/content/drive/MyDrive/P test")
# Out:
# 64

# %%
#STORING ALL P FILES IN LIST
import shutil
path=r"/content/drive/MyDrive/GAN/synthetic images0-0.5"
i=0
arr=[]
for root,dir, files in os.walk(path):
  for file in files:
    if file.endswith("png"):
      arr.append(files)
    #source=path+"/"+files
  #shutil.copy(source, "/content/drive/MyDrive/Colab Notebooks/data/test/Pneumonia")
print(arr)
print(len(arr))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#MOVING FILES TO ANOTHER DIRECTORY FOR BACK UP
path="/content/drive/MyDrive/GAN/synthetic images0-0.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

# %%
path="/content/drive/MyDrive/GAN/synthetic images0.5-1" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")



######################################################################################
path="/content/drive/MyDrive/GAN/synthetic images1-1.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


path="/content/drive/MyDrive/GAN/synthetic images1.5-2" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images2-2.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images2.5-3" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images3-3.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images3.5-4" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images4-4.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images4.5-5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images5-5.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images5.5-6" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images6-6.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images6.5-7" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images7-7.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images7.5-8" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images8-8.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images8.5-9" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images9-9.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images9.5-10" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

# %%
######################################################################################
path="/content/drive/MyDrive/GAN/synthetic images10-10.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


path="/content/drive/MyDrive/GAN/synthetic images10.5-11" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


######################################################################################
path="/content/drive/MyDrive/GAN/synthetic images11-11.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


path="/content/drive/MyDrive/GAN/synthetic images11.5-12" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")



###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images12-12.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images12.5-13" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images13-13.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images13.5-14" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images14-14.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images14.5-15" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images15-15.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images15.5-16" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images16-16.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images16.5-17" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images17-17.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images17.5-18" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images18-18.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images18.5-19" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images19-19.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images19.5-20" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

# %%
path="/content/drive/MyDrive/GAN/synthetic images20-20.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


path="/content/drive/MyDrive/GAN/synthetic images20.5-21" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")



######################################################################################
path="/content/drive/MyDrive/GAN/synthetic images21-21.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


path="/content/drive/MyDrive/GAN/synthetic images21.5-22" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images22-22.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images22.5-23" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images23-23.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images23.5-24" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images24-24.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images24.5-25" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images25-25.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images25.5-26" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images26-26.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images26.5-27" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images27-27.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images27.5-28" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images28-28.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images28.5-29" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")


###############################################################################
path="/content/drive/MyDrive/GAN/synthetic images29-29.5" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")
      

path="/content/drive/MyDrive/GAN/synthetic images29.5-30" 
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, r"/content/drive/MyDrive/GAN/generated images")

# %%
import shutil
path=r"/content/drive/MyDrive/GAN/generated images"
i=0
arr=[]
for files in os.listdir(path):
    arr.append(files)
    #source=path+"/"+files
  #shutil.copy(source, "/content/drive/MyDrive/Colab Notebooks/data/test/Pneumonia")
print(len(arr))
# Out:
# 30000

# %%
#RNADOMLY SELECTING FEW FILES FROM THE ABOVE LIST TO PUT IN TEST FOLDER
import random

# initializing the value of n
n = 23742
  
# printing n elements from list
rand_arr=random.sample(arr, n)
print(rand_arr)
print(len(rand_arr))
# Out:
# ['generated_img_128x128_e12982.png', 'generated_img_128x128_e20655.png', 'generated_img_128x128_e26377.png', 'generated_img_128x128_e8602.png', 'generated_img_128x128_e15554.png', 'generated_img_128x128_e7441.png', 'generated_img_128x128_e22565.png', 'generated_img_128x128_e12733.png', 'generated_img_128x128_e6192.png', 'generated_img_128x128_e21166.png', 'generated_img_128x128_e19983.png', 'generated_img_128x128_e549.png', 'generated_img_128x128_e23352.png', 'generated_img_128x128_e6520.png', 'generated_img_128x128_e7861.png', 'generated_img_128x128_e8491.png', 'generated_img_128x128_e28015.png', 'generated_img_128x128_e12875.png', 'generated_img_128x128_e13690.png', 'generated_img_128x128_e8529.png', 'generated_img_128x128_e14280.png', 'generated_img_128x128_e29115.png', 'generated_img_128x128_e641.png', 'generated_img_128x128_e5574.png', 'generated_img_128x128_e27504.png', 'generated_img_128x128_e26759.png', 'generated_img_128x128_e13194.png', 'generated_img_128x128_e22303.png', '
# ...

# %%
for files in rand_arr:
      if os.path.exists(path+"/"+files):
        source=path+"/"+files
        shutil.copy(source, r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/P")

# %%
count=0
for f in os.listdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/P"):
  count=count+1
print(count)
# Out:
# 258

# %%
count=0

for f in os.listdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/test/P"):
  if f.startswith("gen"):
     break  
  else:
    print(f)
    count=count+1
print(count)

# %%
count=0

for f in os.listdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/P"):
      count=count+1
print(count)
# Out:
# 24000

# %% [markdown]
# JUST PRINT LIST OF FILES

# %%
# STORING ALL FILES IN LIST
import shutil
import os
path=r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/test/P"
i=0
arr=[]
for files in os.listdir(path):
    arr.append(files)
    source=path+"/"+files
  #shutil.copy(source, "/content/drive/MyDrive/Colab Notebooks/data/test/Pneumonia")
print(arr)
# Out:
# ['generated_img_128x128_e5670.png', 'generated_img_128x128_e18793.png', 'generated_img_128x128_e24167.png', 'generated_img_128x128_e21404.png', 'generated_img_128x128_e3796.png', 'generated_img_128x128_e24652.png', 'generated_img_128x128_e5589.png', 'generated_img_128x128_e18543.png', 'generated_img_128x128_e27903.png', 'generated_img_128x128_e17256.png', 'generated_img_128x128_e1387.png', 'generated_img_128x128_e11493.png', 'generated_img_128x128_e26055.png', 'generated_img_128x128_e19818.png', 'generated_img_128x128_e20155.png', 'generated_img_128x128_e29074.png', 'generated_img_128x128_e24571.png', 'generated_img_128x128_e24243.png', 'generated_img_128x128_e19039.png', 'generated_img_128x128_e15128.png', 'generated_img_128x128_e1857.png', 'generated_img_128x128_e6189.png', 'generated_img_128x128_e21002.png', 'generated_img_128x128_e19841.png', 'generated_img_128x128_e25259.png', 'generated_img_128x128_e18775.png', 'generated_img_128x128_e26174.png', 'generated_img_128x128_e8106.pn
# ...

# %%
destination="/content/drive/MyDrive/GAN/synthetic images22-22.5" 
path=r"/content/drive/MyDrive/GAN/generated images"
for f in os.listdir(path):
      #if os.path.exists("/content/drive/MyDrive/GAN/synthetic images0-0.5"+"/"+f):
        source=path+"/"+f
        shutil.move(source, destination)

# %% [markdown]
# FOR OMAMA

# %%
destination="/content/drive/MyDrive/synthetic images22-22.5" 
path=r"/content/drive/MyDrive/GAN/generated images"
import shutil
#for f in os.listdir(path):

for i in range(22000,22500):
 # if os.path.exists('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)):
    print('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i))
    source='/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)
    shutil.copy(source, destination)
# Out:
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22000.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22001.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22002.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22003.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22004.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22005.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22006.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22007.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22008.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22009.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22010.png
# /content/drive/MyDrive/GAN/generated images/generated_img_128x128_e22011.png
# ...

# %%
destination="/content/drive/MyDrive/synthetic images6.5-7" 
path=r"/content/drive/MyDrive/GAN/generated images"
import shutil
#for f in os.listdir(path):

for i in range(6500,7000):
  if os.path.exists('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)):
  #  print('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i))
    source='/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)
    shutil.copy(source, destination)

# %%
destination="/content/drive/MyDrive/synthetic images17.5-18" 
path=r"/content/drive/MyDrive/GAN/generated images"
import shutil
#for f in os.listdir(path):

for i in range(17500,18000):
  if os.path.exists('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)):
  #  print('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i))
    source='/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)
    shutil.copy(source, destination)

# %%
destination="/content/drive/MyDrive/synthetic images25.5.-26" 
path=r"/content/drive/MyDrive/GAN/generated images"
import shutil
#for f in os.listdir(path):

for i in range(25500,26000):
  if os.path.exists('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)):
  #  print('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i))
    source='/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)
    shutil.copy(source, destination)

# %%
destination="/content/drive/MyDrive/synthetic images26-26.5" 
path=r"/content/drive/MyDrive/GAN/generated images"
import shutil
#for f in os.listdir(path):

for i in range(26000,26500):
  if os.path.exists('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)):
  #  print('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i))
    source='/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)
    shutil.copy(source, destination)

# %%
destination="/content/drive/MyDrive/synthetic images28-28.5" 
path=r"/content/drive/MyDrive/GAN/generated images"
import shutil
#for f in os.listdir(path):

for i in range(28000,28500):
  if os.path.exists('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)):
  #  print('/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i))
    source='/content/drive/MyDrive/GAN/generated images/generated_img_128x128_e%03d.png' % (i)
    shutil.copy(source, destination)

# %% [markdown]
# WPGAN VALIDATION TRAIN TEST SPLIT

# %%
len(os.listdir("DIRout"))

# %%
os.mkdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/test/P")
os.mkdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/P")

# %%
path="/content/drive/MyDrive/P images/test/P test"
for files in os.listdir(path):
  source= path +"/"+files
  shutil.copy(source, "/content/drive/MyDrive/Fyp Dataset (rar file extraction)/test/P")

# %%
os.mkdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/validation")
os.mkdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/validation/P")

# STORING ALL FILES IN LIST
import shutil
path=r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/P"
i=0
arr=[]
for files in os.listdir(path):
    arr.append(files)
  
print(len(arr))


#RNADOMLY SELECTING FEW FILES FROM THE ABOVE LIST TO PUT IN TEST FOLDER
import random

# initializing the value of n
n = 48
  
# printing n elements from list
rand_arr=random.sample(arr, n)
print(rand_arr)
print(len(rand_arr))

##MOVING FILES
for files in rand_arr:
      if os.path.exists(path+"/"+files):
        source=path+"/"+files
        shutil.move(source, r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/validation/P")
# Out:
# 258
# ['00013615_024.png', '00000165_001.png', '00009863_058.png', '00003092_000.png', '00014201_008.png', '00021571_000.png', '00016362_000.png', '00025583_005.png', '00018319_001.png', '00000583_045.png', '00012158_021.png', '00001437_019.png', '00006490_006.png', '00010531_073.png', '00015809_015.png', '00025075_006.png', '00010805_042.png', '00014072_002.png', '00012094_009.png', '00014294_011.png', '00013611_001.png', '00012761_007.png', '00009305_002.png', '00011553_045.png', '00012733_000.png', '00003640_004.png', '00001182_004.png', '00010693_012.png', '00013992_005.png', '00016705_004.png', '00011147_000.png', '00012834_085.png', '00003950_002.png', '00007787_001.png', '00021584_001.png', '00001637_001.png', '00003523_011.png', '00007444_003.png', '00006966_004.png', '00015628_018.png', '00020945_021.png', '00029481_004.png', '00025607_001.png', '00006985_002.png', '00012297_004.png', '00011842_002.png', '00020505_022.png', '00005138_009.png']
# 48

# %%
#os.mkdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/validation")
#os.mkdir("/content/drive/MyDrive/Fyp Dataset (rar file extraction)/validation/NF")

# STORING ALL FILES IN LIST
import shutil
path=r"/content/drive/MyDrive/WPGAN2"
i=0
arr=[]
for files in os.listdir(path):
    arr.append(files)
  
print(len(arr))


#RNADOMLY SELECTING FEW FILES FROM THE ABOVE LIST TO PUT IN TEST FOLDER
import random

# initializing the value of n
n = 21000
  
# printing n elements from list
rand_arr=random.sample(arr, n)
print(rand_arr)
print(len(rand_arr))

##MOVING FILES
for files in rand_arr:
      if os.path.exists(path+"/"+files):
        source=path+"/"+files
        shutil.move(source, r"/content/drive/MyDrive/Fyp Dataset (rar file extraction)/train/P")
# Out:
# 21000
# ...

# %%
|
